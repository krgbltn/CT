# %%
ACCESS_TOKEN = "CfDJ8LW0fsEutwxHput_3cmlBf-8Ayc1DhPLD7a5u6MHGzSXlMOdgRMhWcjDvAiyg4EqX3OKExMh7x-i6DeK73X5Oz8L_5jxLh0SOYFp_fP8EamkqQL9-lzgg8IUhEtPiEPzYFIPAKH5L4S1uYIqAktJeG7qpe6ExTLKC4YceXGHLcdR8F-9XUcZrU_tFry89_oYjS7LFhIIG77PCYSkFmGpeEd9pH5PkVSH_Lr76K1BHDQHXh5igRGyEuSoLozA3DrMmW84rudm55bcyYsxC5JQGSwScdBCYZieecaXyBuCCWs9"
DOMAIN = "https://cloud.craft-talk.ru"
PROJECT_ID = "hiring_servispro"
IS_SSL = False

DIALOG_ID = "c65ffe07-877e-4d94-bd43-4ddae9f42eca"

# %%
from src.HistoryMessagesRender import HistoryMessagesRender

history_messages_render = HistoryMessagesRender(ACCESS_TOKEN, DOMAIN, PROJECT_ID, IS_SSL)
history_messages_render.render_history_messages(DIALOG_ID)
# Out:
# ══════════════════════════════════════════════════════════════════════
#   ИНФОРМАЦИЯ О ДИАЛОГЕ
# ══════════════════════════════════════════════════════════════════════
#   Dialog ID     : c65ffe07-877e-4d94-bd43-4ddae9f42eca
#   Customer ID   : hiring_servispro
#   OmniUser ID   : 60980df9-4996-465e-aae1-8e5f81ede473
#   Каналы        : channel_54c50e2
#   Начало        : 2026-05-25 10:01:05 UTC
#   Конец         : 2026-05-25 10:41:43 UTC
#   Длительность  : 40.6 мин
#   Всего событий : 233
#
#   Операторы (2):
#     • Рамил Зейналов  [DEFAULT___zramil816@gmail.com]
#     • Александр Басовский  [DEFAULT___basovskiy_94@mail.ru]
#
# ══════════════════════════════════════════════════════════════════════
#   ХРОНОЛОГИЯ ДИАЛОГА
# ══════════════════════════════════════════════════════════════════════
# [2026-05-25 10:01:05 UTC]  Инициализация диалога
#   👤 КЛИЕНТ
#
# [2026-05-25 10:01:09 UTC]  Сообщение клиента (текст/кнопка)
#   🤖 jsagent
#   ✉  Добро пожаловать!  Это чат с куратором — мы поможем Вам оформить документы, расскажем, как всё устроено, и доведем до пе…
#
# [2026-05-25 10:01:09 UTC]  Назначено оператору
#   🤖 initialmsgagent
#
# [2026-05-25 10:01:09 UTC]  Прочитано клиентом
#   👤 КЛИЕНТ
#
# [2026-05-25 10:01:11 UTC]  Сообщение клиента (текст/кнопка)
#   🤖 aiassist2
#   ✉  В каком городе вы находитесь? Укажите полное название города, пожалуйста
#   🔘 Кнопки: Москва | Сочи | Санкт-Петербург | Видное | Калуга | Московский | Подольск | Орехово-Зуево | Электросталь | Ногинск | Серпухов | Чехов | Другой город
#
# [2026-05-25 10:01:11 UTC]  Прочитано клиентом
#   👤 КЛИЕНТ
#
# [2026-05-25 10:01:22 UTC]  Сообщение клиента (текст/кнопка)
#   👤 КЛИЕНТ
#   🔘 Кнопки: Москва
#
# [2026-05-25 10:01:24 UTC]  Сообщение клиента (текст/кнопка)
#   🤖 aiassist2
#   ✉  На какую роль откликались?
#   🔘 Кнопки: Водитель СБ | Водитель-логист на корпоративном авто | Водитель-логист на своем авто | Ремонтник | Мувер | Скаут | Энерджайзер | Курьер пеший БЕРИ ЗАРЯД | Авточарджер на своем авто ВЕЛОБАЙК | Велочарджер ВЕЛОБАЙК | Скаут ВЕЛОБАЙК | Водитель СБ (Яндекс.Еда) | Мойщик | Перегонщик на мойку | Перегонщик на СТО (Делимобиль) | Перегонщик на СТО (TopDoer) | Перегонщик на СТО (Яндекс) | Замена АКБ в авто | Другая роль | Ремонтник Я.Еда
#
# [2026-05-25 10:01:24 UTC]  Прочитано клиентом
#   👤 КЛИЕНТ
#
# [2026-05-25 10:01:42 UTC]  Сообщение клиента (текст/кнопка)
#   👤 КЛИЕНТ
#   ✉  Здравствуйте
#
# [2026-05-25 10:01:44 UTC]  Сообщение клиента (текст/кнопка)
#   🤖 aiassist2
#   ✉  Напишите, пожалуйста, название роли, на которую откликались
#   🔘 Кнопки: Водитель СБ | Водитель-логист на корпоративном авто | Водитель-логист на своем авто | Ремонтник | Мувер | Скаут | Энерджайзер | Курьер пеший БЕРИ ЗАРЯД | Авточарджер на своем авто ВЕЛОБАЙК | Велочарджер ВЕЛОБАЙК | Скаут ВЕЛОБАЙК | Водитель СБ (Яндекс.Еда) | Мойщик | Перегонщик на мойку | Перегонщик на СТО (Делимобиль) | Перегонщик на СТО (TopDoer) | Перегонщик на СТО (Яндекс) | Замена АКБ в авто | Другая роль | Ремонтник Я.Еда
#
# [2026-05-25 10:01:44 UTC]  Прочитано клиентом
#   👤 КЛИЕНТ
#
# [2026-05-25 10:02:24 UTC]  Сообщение клиента (текст/кнопка)
#   👤 КЛИЕНТ
#   🔘 Кнопки: Перегонщик на СТО (TopDoer)
#
# [2026-05-25 10:02:35 UTC]  Диалог назначен (routing)
#   🔀 routing → Рамил Зейналов
#
# [2026-05-25 10:02:35 UTC]  Назначено оператору
#   🔀 routing → Рамил Зейналов
#
# [2026-05-25 10:02:35 UTC]  Назначено оператору
#   🔀 routing → Рамил Зейналов
#
# [2026-05-25 10:02:35 UTC]  Назначено оператору
#   🔀 routing → Рамил Зейналов
#
# [2026-05-25 10:03:11 UTC]  Сообщение клиента (текст/кнопка)
#   👤 КЛИЕНТ
#   🔘 Кнопки: Перегонщик на СТО (TopDoer)
#
# [2026-05-25 10:03:12 UTC]  Назначено оператору
#   🔀 routing → System System
#
# [2026-05-25 10:06:19 UTC]  Сообщение клиента (текст/кнопка)
#   👤 КЛИЕНТ
#   ✉  Перегонщик СТО( TopDoer)
#
# [2026-05-25 10:06:20 UTC]  Назначено оператору
#   🔀 routing → System System
#
# [2026-05-25 10:06:44 UTC]  Сообщение клиента (текст/кнопка)
#   👤 КЛИЕНТ
#   ✉  Перегонщик на СТО(Яндекс)
#
# [2026-05-25 10:06:44 UTC]  Назначено оператору
#   🔀 routing → System System
#
# [2026-05-25 10:11:52 UTC]  Сообщение клиента (текст/кнопка)
#   🔀 routing → Рамил Зейналов
#   ✉  Добрый день!  К сожалению, набор на данную роль закрыт.  При этом мы можем предложить Вам рассмотреть другие роли. Хотел…
#
# [2026-05-25 10:11:52 UTC]  Прочитано клиентом
#   👤 КЛИЕНТ
#
# [2026-05-25 10:12:44 UTC]  Сообщение клиента (текст/кнопка)
#   👤 КЛИЕНТ
#   ✉  Да
#
# [2026-05-25 10:12:46 UTC]  Назначено оператору
#   🔀 routing → System System
#
# [2026-05-25 10:15:31 UTC]  Сообщение клиента (текст/кнопка)
#   🔀 routing → Александр Басовский
#   ✉  Могу предложить рассмотреть  Курьер (Авто, Вело, Пеший) Яндекс Еда, Курьер Бери Заряд (доставка повербанков)  Водитель- …
#
# [2026-05-25 10:15:32 UTC]  Прочитано клиентом
#   👤 КЛИЕНТ
#
# [2026-05-25 10:17:32 UTC]  Сообщение клиента (текст/кнопка)
#   👤 КЛИЕНТ
#   ✉  Доставка повербанков, водитель логист, мастер смены
#
# [2026-05-25 10:17:34 UTC]  Назначено оператору
#   🔀 routing → System System
#
# [2026-05-25 10:18:08 UTC]  Сообщение клиента (текст/кнопка)
#   🔀 routing → Александр Басовский
#   ✉  Информация о роли Пешего Курьера Бери Заряд  \ Функционал:  Пополнять и забирать пауэрбанки из зарядных станций.  Смены …
#
# [2026-05-25 10:18:08 UTC]  Прочитано клиентом
#   👤 КЛИЕНТ
#
# [2026-05-25 10:18:26 UTC]  Сообщение клиента (текст/кнопка)
#   🔀 routing → Александр Басовский
#   ✉  Информация о роли водителя в Москве  \ Функционал:  Передвижение по городу на корпоративном авто с целью:  * Обеспечение…
#
# [2026-05-25 10:18:27 UTC]  Прочитано клиентом
#   👤 КЛИЕНТ
#
# [2026-05-25 10:18:39 UTC]  Сообщение клиента (текст/кнопка)
#   🤖 aiassist2
#   ✉  Информация о роли мастера смены в Москве (а также в Видном, Жуковском, Королеве)  \ Функционал:  * Выдача АКБ для замены…
#
# [2026-05-25 10:18:39 UTC]  Прочитано клиентом
#   👤 КЛИЕНТ
#
# [2026-05-25 10:18:46 UTC]  Сообщение клиента (текст/кнопка)
#   👤 КЛИЕНТ
#   ✉  Да
#
# [2026-05-25 10:18:48 UTC]  Назначено оператору
#   🔀 routing → System System
#
# [2026-05-25 10:20:54 UTC]  Сообщение клиента (текст/кнопка)
#   🔀 routing → Александр Басовский
#   ✉  Подскажите, пожалуйста, какая роль Вас заинтересовала?
#
# [2026-05-25 10:20:55 UTC]  Прочитано клиентом
#   👤 КЛИЕНТ
#
# [2026-05-25 10:41:42 UTC]  Сообщение клиента (текст/кнопка)
#   🤖 aiassist2
#   ✉  Ждем вашего ответа :)
#
# [2026-05-25 10:41:43 UTC]  Прочитано клиентом
#   👤 КЛИЕНТ
#
# [2026-05-25 10:41:43 UTC]  Диалог завершён оператором
#   🤖 botmediator
#   ✉  push_sent
#
# ══════════════════════════════════════════════════════════════════════
#   СТАТИСТИКА
# ══════════════════════════════════════════════════════════════════════
#   Распределение событий по типам:
#        0 — Type 0: 1
#        1 — Сообщение клиента (текст/кнопка): 20
#        2 — Прочитано клиентом: 11
#       11 — Сообщение обработано ботом: 9
#       12 — Назначено оператору: 10
#       16 — Диалог завершён оператором: 1
#       18 — Диалог назначен (routing): 1
#       30 — Системная команда бота: 163
#       33 — Инициализация диалога: 1
#      202 — Оператор начал печатать: 7
#      203 — Оператор остановил печать: 7
#      204 — Type 204: 1
#      205 — Type 205: 1
#
#   Текстовых сообщений от клиента: 6
#     → Здравствуйте
#     → Перегонщик СТО( TopDoer)
#     → Перегонщик на СТО(Яндекс)
#     → Да
#     → Доставка повербанков, водитель логист, мастер смены
#     → Да
#
#   Ответов операторов: 5
#     [Рамил Зейналов] Добрый день!
#
# К сожалению, набор на данную роль закрыт.
#
# При этом мы можем предложить Вам рассмотрет
#     [Александр Басовский] Могу предложить рассмотреть
#
# Курьер (Авто, Вело, Пеший) Яндекс Еда,
# Курьер Бери Заряд (доставка пове
#     [Александр Басовский] Информация о роли Пешего Курьера Бери Заряд
#
# \
# Функционал:
#
# Пополнять и забирать пауэрбанки из заряд
#     [Александр Басовский] Информация о роли водителя в Москве
#
# \
# Функционал:
#
# Передвижение по городу на корпоративном авто с ц
#     [Александр Басовский] Подскажите, пожалуйста, какая роль Вас заинтересовала?
#
#   Переключений бота (switchredirect): 5
#     → /switchredirect start_agent intent_id="article-122385c5-ec49-43d0-b379-774a10f24d04"
#     → /switchredirect route_night_agent
#     → /switchredirect kicksh_night_agent
#     → /schedule name=push_article_60980df9-4996-465e-aae1-8e5f81ede473 time=7200000 /switchredirect aiassist2 intent_id="article-3fc6dc32-ac97-406b-847b-d3f8f107eeb1"
#     → /switchredirect on_push_sent
#
#
# ══════════════════════════════════════════════════════════════════════
#   БОТ: путь интентов и содержимое статей
# ══════════════════════════════════════════════════════════════════════
#
# ============================================================
# ARTICLE: article-0e9b1908-cfbb-48ea-9c51-17a2e03adacb
# --- block_3c7bde4 [Condition] ---
# IF channel_id == 'channel_2991f92'
#     → block_f888ac
# IF channel_id == 'channel_1113ccb'
#     → block_f888ac
# ELSE
#     → block_f888ac
#
#
# ============================================================
# ARTICLE: article-cffedecf-b0f1-4e58-a38e-a5a1c47e9b9d
# --- block_5185031 [Condition] ---
# IF flow == 'transfer_operator'
#     → block_170b5b6
# ELSE
#     → block_1c69af
# --- block_1c69af [Message] ---
# /schedule name=set_kurator_{{sys_omniuserid}} time=300000 /redirect aiassist2 intent_id="article-4c4d9924-08e8-4789-a0ea-7ebad855a084"
# --- block_3810c2d [Form] ---
# Form block with slots:
#  - city_26 (mandatory)
# Output conditions:
#  - Условие перехода на condition_27b328: __ALL_MANDATORY_FILLED_IN__
# --- block_293a0fd [Message] ---
# /switchredirect start_agent intent_id="{{city_26}}"
#
# ============================================================
# ARTICLE: article-122385c5-ec49-43d0-b379-774a10f24d04
# --- block_70da66 [Form] ---
# Form block with slots:
#  - role_moscow1 (mandatory)
# Output conditions:
#  - Условие перехода на condition_5efe5df: __ALL_MANDATORY_FILLED_IN__
#  - Условие перехода на condition_57e3cc0: role_moscow1 attempts = 2
# --- block_25b98b [Command] ---
# Command: SET_SLOT_VALUE_role_moscow {{role_moscow1}}
# Output -> block_179abf6
#
# --- block_179abf6 [Command] ---
# Command: SET_SLOT_VALUE_role {{role_moscow.title}}
# Output -> block_1f9d6c4
#
# --- block_1f9d6c4 [Command] ---
# Command: SET_SLOT_VALUE_city city_1
# Output -> block_39e0d65
#
# --- block_39e0d65 [Condition] ---
# IF role_moscow == 'role_moscow_transfer_wash'
#     → block_28b02be
# IF role_moscow == 'role_moscow_urgent_tire'
#     → block_28b02be
# IF role_moscow == 'role_moscow_stat_tire'
#     → block_28b02be
# IF role_moscow == 'role_moscow_transfer_sto_deli'
#     → block_28b02be
# IF role_moscow == 'role_moscow_transfer_sto_top'
#     → block_28b02be
# IF role_moscow == 'role_moscow_transfer_sto_yandex'
#     → block_28b02be
# IF role_moscow == 'role_moscow_transfer_sshm'
#     → block_28b02be
# IF role_moscow == 'role_moscow_battery'
#     → block_28b02be
# IF role_moscow == 'role_moscow_washer'
#     → block_28b02be
# ELSE
#     → block_1960ffd
# --- block_28b02be [Command] ---
# Command: SET_SLOT_VALUE_routing_queue c867f994-30b8-40f3-99b2-19451f27967c
# Output -> block_2d866bf
#
# --- block_2d866bf [Form] ---
# Form block with slots:
#  - nationality (mandatory)
# Output conditions:
#  - Условие перехода на condition_1f14581: __ALL_MANDATORY_FILLED_IN__
#  - Условие перехода на condition_53f9d3c: nationality attempts = 2
# --- block_4716c9c [Condition] ---
# IF nationality == 'other'
#     → block_3bcad99
# ELSE
#     → block_5464ece
# --- block_5464ece [Form] ---
# Form block with slots:
#  - age (mandatory)
# Output conditions:
#  - Условие перехода на condition_318162e: __ALL_MANDATORY_FILLED_IN__
# --- block_2c70248 [Condition] ---
# IF role_moscow == 'role_moscow_driver_sb'
#     → block_5cc90f7
# IF role_moscow == 'role_moscow_logist_corp'
#     → block_66ca78
# IF role_moscow == 'role_moscow_logist_self'
#     → block_66ca78
# IF role_moscow == 'role_moscow_repair'
#     → block_74e4bb
# IF role_moscow == 'role_moscow_mover'
#     → block_242a27
# IF role_moscow == 'role_moscow_scout'
#     → block_242a27
# IF role_moscow == 'role_moscow_shift_master'
#     → block_66ca78
# IF role_moscow == 'role_moscow_shift_master_warehouse'
#     → block_66ca78
# IF role_moscow == 'role_moscow_energizer'
#     → block_242a27
# IF role_moscow == 'role_moscow_tech_mount'
#     → block_28ff3e5
# IF role_moscow == 'role_moscow_tech_assembler'
#     → block_28ff3e5
# IF role_moscow == 'role_moscow_tech_service'
#     → block_276f4a5
# IF role_moscow == 'role_moscow_courier_pesh_beri'
#     → block_66ca78
# IF role_moscow == 'role_moscow_autocourier_beri'
#     → block_f2164f
# IF role_moscow == 'role_moscow_field_engineer'
#     → block_59dc0f2
# IF role_moscow == 'role_moscow_autocharger_velo'
#     → block_66ca78
# IF role_moscow == 'role_moscow_velocharger'
#     → block_bc3c1e
# IF role_moscow == 'role_moscow_scout_velo'
#     → block_bc3c1e
# IF role_moscow == 'role_moscow_repair_yae'
#     → block_f2164f
# IF role_moscow == 'role_moscow_driver_sb_yae'
#     → block_5cc90f7
# IF role_moscow == 'role_moscow_washer'
#     → block_59dc0f2
# IF role_moscow == 'role_moscow_transfer_wash'
#     → block_28ff3e5
# IF role_moscow == 'role_moscow_urgent_tire'
#     → block_2724237
# IF role_moscow == 'role_moscow_stat_tire'
#     → block_1cd08d1
# IF role_moscow == 'role_moscow_transfer_sto_deli'
#     → block_28ff3e5
# IF role_moscow == 'role_moscow_transfer_sto_top'
#     → block_28ff3e5
# IF role_moscow == 'role_moscow_transfer_sto_yandex'
#     → block_42faa
# IF role_moscow == 'role_moscow_transfer_sshm'
#     → block_42faa
# IF role_moscow == 'role_moscow_battery'
#     → block_443f13d
# IF role_moscow == 'role_moscow_courier_yae_auto'
#     → block_1f98036
# IF role_moscow == 'role_moscow_courier_yae_bike'
#     → block_1f98036
# IF role_moscow == 'role_moscow_courier_yae_pesh'
#     → block_1f98036
# IF role_moscow == 'role_moscow_courier_magnit_auto'
#     → block_1f98036
# IF role_moscow == 'role_moscow_courier_magnit_pesh'
#     → block_1f98036
# IF role_moscow == 'role_moscow_courier_magnit_bike'
#     → block_1f98036
# IF role_moscow == 'role_moscow_courier_magnit_ebike'
#     → block_1f98036
# IF role_moscow == 'role_moscow_other'
#     → block_54f28c
# ELSE
#     → block_54f28c
# --- block_28ff3e5 [Condition] ---
# IF age == '>=20 and <=50'
#     → block_4d8f6c0
# ELSE
#     → block_54f28c
# --- block_4d8f6c0 [Form] ---
# Form block with slots:
#  - name (mandatory)
#  - phone_numer (mandatory)
# Output conditions:
#  - Условие перехода на condition_1d5cdfd: __ALL_MANDATORY_FILLED_IN__
# --- block_173499f [Condition] ---
# IF role_moscow == 'role_moscow_transfer_wash'
#     → block_4b4e6e6
# IF role_moscow == 'role_moscow_urgent_tire'
#     → block_4b4e6e6
# IF role_moscow == 'role_moscow_transfer_sto_deli'
#     → block_4b4e6e6
# IF role_moscow == 'role_moscow_transfer_sto_top'
#     → block_4b4e6e6
# IF role_moscow == 'role_moscow_transfer_sto_yandex'
#     → block_4b4e6e6
# IF role_moscow == 'role_moscow_transfer_sshm'
#     → block_4b4e6e6
# ELSE
#     → block_109dbb3
# --- block_4b4e6e6 [Form] ---
# Form block with slots:
#  - driving_experience (mandatory)
# Output conditions:
#  - Условие перехода на condition_5bb9470: __ALL_MANDATORY_FILLED_IN__
# --- block_30bbadf [Condition] ---
# IF driving_experience == '>=2'
#     → block_d212cc
# ELSE
#     → block_d212cc
#
#
# ============================================================
# ARTICLE: article-4c4d9924-08e8-4789-a0ea-7ebad855a084
# --- block_389664c [Form] ---
# Form block with slots:
#  - name (mandatory)
#  - phone_numer (mandatory)
# Output conditions:
#  - Условие перехода на condition_b2c265: __ALL_MANDATORY_FILLED_IN__
# --- block_2a54c4 [Message] ---
# /delete_schedule name=set_kurator_{{sys_omniuserid}}
# --- block_510211f [Condition] ---
# IF name == 'None' AND role == 'None' AND phone_numer == 'None'
#     → block_1467b8f
# ELSE
#     → block_29e95a0
# --- block_1467b8f [Command] ---
# Command: SET_SLOT_VALUE_sys_firstname {{name}}
# Output -> block_2c5d6ac
#
# --- block_2c5d6ac [Condition] ---
# IF city == 'None'
#     → block_2b05ea0
# ELSE
#     → block_56a2de4
# --- block_2b05ea0 [Command] ---
# Command: SET_SLOT_VALUE_city_str {{city.title}}
# Output -> block_1430445
#
# --- block_1430445 [Command] ---
# Command: SET_SLOT_VALUE_WITH_EXPRESSION_sys_lastname {{city_str}} + " " + {{role}}
# Output -> block_7a7749
#
# --- block_7a7749 [Command] ---
# Command: SET_SLOT_VALUE_WITH_EXPRESSION_sys_middlename {{phone_numer}}
# Output -> block_b2f02d
#
#
#
# ============================================================
# ARTICLE: article-a3d9d3f5-9940-47c7-b2e1-05067d99cf15
# --- block_44aef4c [Message] ---
# /delete_schedule name=push_{{sys_omniuserid}}
# --- block_3125245 [Message] ---
# /delete_schedule name=push_article_{{sys_omniuserid}}
# --- block_20c02c5 [Message] ---
# /delete_schedule name=push_sent_{{sys_omniuserid}}
# --- block_4caecc4 [Message] ---
# /delete_schedule name=push_sent_{{copy_omniuserid}}
# --- block_2a2a0b6 [Command] ---
# Command: SET_SLOT_VALUE_flow transfer_operator
# Output -> block_39cbcfb
#
# --- block_39cbcfb [Command] ---
# Command: SET_SLOT_VALUE_skip_score true
# Output -> block_5b576c2
#
# --- block_5b576c2 [Agent] ---
# Agent block: route_night_agent (fixedreplyagent)
#
# ============================================================
# ARTICLE: article-89f38b77-5489-4fbf-90eb-a491f525f085
# --- block_188eb53 [Condition] ---
# IF channel_id == 'channel_14ab6e4'
#     → block_37c652d
# IF channel_id == 'channel_54c50e2'
#     → block_42a418a
# IF channel_id == 'integration_channel_max_hiring'
#     → block_42a418a
# IF channel_id == 'channel_a99341'
#     → block_42a418a
# ELSE
#     → block_37c652d
# --- block_42a418a [Agent] ---
# Agent block: kicksh_night_agent (nightagent)
#
# ============================================================
# ARTICLE: article-82430562-ed5d-4602-9fab-64fd46fc7203
#
# ========== ARTICLE ==========
# Title: Стартовое МС МСК 2026
# SymbolCode: article-82430562-ed5d-4602-9fab-64fd46fc7203
# Id: 3f4dc7f7-77fc-4689-95ce-9b2c26f93d5a
#
# [Answer Id: 7be43a02-737c-4877-ad79-6f8b1e452b07]
# Cообщение:
# Информация о роли мастера смены в Москве (а также в Видном, Жуковском, Королеве)
#
# \
# Функционал:
#
# * Выдача АКБ для замены в электросамокатах и контроль зарядки сданных АКБ;
# * Фиксация выданных и сданных АКБ в техническом приложении;
# * Контроль выхода в смену исполнителей по замене АКБ.
#
# \
# Смены по 12 часов (с 9 до 21 или с 21 до 9). Даты смен и район вы выбираете самостоятельно, количество смен выбираете сами.
#
# Выплаты ежедневные (через день после смены, кроме выходных и праздничных дней).
#
# Оформление через самозанятость (компания компенсирует 6% на оплату налогов).
#
# \
# Оплата 2340 рублей за смену.
#
# **Программа лояльности**: за каждый слот будут начисляться баллы, которые можно обменять на мерч (худи, термокружки) или технику, а в конце сезона будут разыграны iPhone 17, MacBook Air и AirPods Max среди самых надежных профи!
#
# \
# Подскажите, пожалуйста, подходят ли Вам условия?
# Условие:
#   - None
#
#
# ============================================================
# ARTICLE: article-b751653e-53d0-4475-a0e1-4e4e9eb79166
#
# ========== ARTICLE ==========
# Title: Отложенное удержание
# SymbolCode: article-b751653e-53d0-4475-a0e1-4e4e9eb79166
# Id: bfb5f585-93a5-4e62-8866-a8306445d1df
#
# [Answer Id: 5698b881-3804-4c3c-84e5-104647920aba]
# Cообщение:
# REDIRECT_TO_INTENT article-5a33ade9-76bb-426c-8acf-03183967e463
# Условие:
#   - None
#
#
# ============================================================
# ARTICLE: article-5a33ade9-76bb-426c-8acf-03183967e463
#
#
# ============================================================
# ARTICLE: article-d6d1c902-f276-4892-bab8-1641c8b49cad
# --- block_99e645 [Condition] ---
# IF {{timeslot}} > NOW_MS
#     → block_128f28c
# IF channel_id == 'channel_14ab6e4'
#     → block_52970b4
# IF channel_id == 'channel_54c50e2'
#     → block_2c8dafe
# IF channel_id == 'channel_3b69d70'
#     → block_2c8dafe
# ELSE
#     → block_2c8dafe
# --- block_2c8dafe [Condition] ---
# IF hour(NOW)>=17 or hour(NOW)<5
#     → block_e2ec97
# ELSE
#     → block_4bd04a0
# --- block_4bd04a0 [Message] ---
# /schedule name=push_article_{{sys_omniuserid}} time=7200000 /switchredirect aiassist2 intent_id="article-3fc6dc32-ac97-406b-847b-d3f8f107eeb1"
#
#
# ============================================================
# ARTICLE: article-f3b12f4f-baf1-4fae-b573-28d83053b296
# --- block_39990e4 [Message] ---
# Ждем вашего ответа :)
# --- block_523013f [Agent] ---
# Agent block: on_push_sent (finishdialogagent)
