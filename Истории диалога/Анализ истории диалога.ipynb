# %%
ACCESS_TOKEN = "ваш токен доступа"
DOMAIN = "https://cloud.craft-talk.com"
PROJECT_ID = "docs"
IS_SSL = True

DIALOG_ID = "143c1dde-2a88-472f-b797-f20147557f64"

# %%
from src.HistoryMessagesRender import HistoryMessagesRender

history_messages_render = HistoryMessagesRender(ACCESS_TOKEN, DOMAIN, PROJECT_ID, IS_SSL)
history_messages_render.render_history_messages(DIALOG_ID)
# Out:
# ══════════════════════════════════════════════════════════════════════
#   ИНФОРМАЦИЯ О ДИАЛОГЕ
# ══════════════════════════════════════════════════════════════════════
#   Dialog ID     : 143c1dde-2a88-472f-b797-f20147557f64
#   Customer ID   : ct_support
#   OmniUser ID   : 615819c7-a283-4858-9f33-33aeacebb08f
#   Каналы        : channel_51bc183
#   Начало        : 2026-05-01 12:49:43 UTC
#   Конец         : 2026-05-01 13:04:45 UTC
#   Длительность  : 15.0 мин
#   Всего событий : 92
#
#   Вложения (12):
#     📎 message.eml
#     📎 message.eml
#     📎 message.eml
#     📎 message.eml
#     📎 message.eml
#     📎 message.eml
#     📎 message.eml
#     📎 message.eml
#     📎 message.eml
#     📎 message.eml
#     📎 message.eml
#     📎 message.eml
#
# ══════════════════════════════════════════════════════════════════════
#   ХРОНОЛОГИЯ ДИАЛОГА
# ══════════════════════════════════════════════════════════════════════
# [2026-05-01 12:49:43 UTC]  Инициализация диалога
#   👤 КЛИЕНТ
#   ✉  Простите, не понял вас.&lt;br&gt;classification_failed_nayd&lt;br&gt;=======&lt;br&gt;CraftTalk&lt;br&gt; &lt;br&gt; &lt…
#
# [2026-05-01 12:49:43 UTC]  Сообщение клиента (текст/кнопка)
#   👤 КЛИЕНТ
#   ✉  Простите, не понял вас.&lt;br&gt;classification_failed_nayd&lt;br&gt;=======&lt;br&gt;CraftTalk&lt;br&gt; &lt;br&gt; &lt…
#
# [2026-05-01 12:49:44 UTC]  Сообщение клиента (текст/кнопка)
#   👤 КЛИЕНТ
#   ✉  Таймаут - 1&lt;br&gt;=======&lt;br&gt;CraftTalk&lt;br&gt; &lt;br&gt; &lt;div&gt;01.05.2026 11:10, buggy4test@mail.ru:&lt…
#
# [2026-05-01 12:49:45 UTC]  Сообщение клиента (текст/кнопка)
#   👤 КЛИЕНТ
#   ✉  Таймаут - 1&lt;br&gt;=======&lt;br&gt;CraftTalk&lt;br&gt; &lt;br&gt; &lt;div&gt;01.05.2026 11:10, mailer-daemon@corp.mai…
#
# [2026-05-01 12:49:46 UTC]  Сообщение клиента (текст/кнопка)
#   🤖 aiassist2
#   ✉  Простите, не понял вас. classification_failed_nayd
#
# [2026-05-01 12:49:47 UTC]  Сообщение клиента (текст/кнопка)
#   🤖 aiassist2
#   ✉  Простите, не понял вас. classification_failed_nayd
#
# [2026-05-01 12:49:47 UTC]  Сообщение клиента (текст/кнопка)
#   🤖 aiassist2
#   ✉  Слот Для проверки regex - пустой
#
# [2026-05-01 12:49:48 UTC]  Прочитано клиентом
#   👤 КЛИЕНТ
#
# [2026-05-01 12:49:49 UTC]  Прочитано клиентом
#   👤 КЛИЕНТ
#
# [2026-05-01 12:49:50 UTC]  Прочитано клиентом
#   👤 КЛИЕНТ
#
# [2026-05-01 12:52:47 UTC]  Сообщение клиента (текст/кнопка)
#   🤖 timerservice
#   ✉  Таймаут - 1
#
# [2026-05-01 12:52:48 UTC]  Прочитано клиентом
#   👤 КЛИЕНТ
#
# [2026-05-01 12:54:47 UTC]  Сообщение клиента (текст/кнопка)
#   🤖 timerservice
#   ✉  Таймаут - 2
#
# [2026-05-01 12:54:49 UTC]  Сообщение клиента (текст/кнопка)
#   👤 КЛИЕНТ
#   ✉  Таймаут - 2&lt;br&gt;=======&lt;br&gt;CraftTalk&lt;br&gt; &lt;br&gt; &lt;div&gt;01.05.2026 11:12, buggy4test@mail.ru:&lt…
#
# [2026-05-01 12:54:51 UTC]  Сообщение клиента (текст/кнопка)
#   👤 КЛИЕНТ
#   ✉  Таймаут - 2&lt;br&gt;=======&lt;br&gt;CraftTalk&lt;br&gt; &lt;br&gt; &lt;div&gt;01.05.2026 11:12, mailer-daemon@corp.mai…
#
# [2026-05-01 12:54:52 UTC]  Сообщение клиента (текст/кнопка)
#   🤖 aiassist2
#   ✉  Простите, не понял вас. classification_failed_nayd
#
# [2026-05-01 12:54:52 UTC]  Сообщение клиента (текст/кнопка)
#   🤖 aiassist2
#   ✉  Простите, не понял вас. classification_failed_nayd
#
# [2026-05-01 12:54:53 UTC]  Сообщение клиента (текст/кнопка)
#   👤 КЛИЕНТ
#   ✉  Простите, не понял вас.&lt;br&gt;classification_failed_nayd&lt;br&gt;=======&lt;br&gt;CraftTalk&lt;br&gt; &lt;br&gt; &lt…
#
# [2026-05-01 12:54:55 UTC]  Сообщение клиента (текст/кнопка)
#   👤 КЛИЕНТ
#   ✉  Простите, не понял вас.&lt;br&gt;classification_failed_nayd&lt;br&gt;=======&lt;br&gt;CraftTalk&lt;br&gt; &lt;br&gt; &lt…
#
# [2026-05-01 12:54:56 UTC]  Сообщение клиента (текст/кнопка)
#   🤖 aiassist2
#   ✉  Простите, не понял вас. classification_failed_nayd
#
# [2026-05-01 12:54:56 UTC]  Сообщение клиента (текст/кнопка)
#   👤 КЛИЕНТ
#   ✉  Простите, не понял вас.&lt;br&gt;classification_failed_nayd&lt;br&gt;=======&lt;br&gt;CraftTalk&lt;br&gt; &lt;br&gt; &lt…
#
# [2026-05-01 12:54:57 UTC]  Сообщение клиента (текст/кнопка)
#   🤖 aiassist2
#   ✉  Простите, не понял вас. classification_failed_nayd
#
# [2026-05-01 12:54:57 UTC]  Сообщение клиента (текст/кнопка)
#   🤖 aiassist2
#   ✉  Простите, не понял вас. classification_failed_nayd
#
# [2026-05-01 12:57:57 UTC]  Сообщение клиента (текст/кнопка)
#   🤖 timerservice
#   ✉  Таймаут - 1
#
# [2026-05-01 12:57:59 UTC]  Прочитано клиентом
#   👤 КЛИЕНТ
#
# [2026-05-01 12:59:58 UTC]  Сообщение клиента (текст/кнопка)
#   🤖 timerservice
#   ✉  Таймаут - 2
#
# [2026-05-01 12:59:59 UTC]  Прочитано клиентом
#   👤 КЛИЕНТ
#
# [2026-05-01 13:00:33 UTC]  Сообщение клиента (текст/кнопка)
#   👤 КЛИЕНТ
#   ✉  Простите, не понял вас.&lt;br&gt;classification_failed_nayd&lt;br&gt;=======&lt;br&gt;CraftTalk&lt;br&gt; &lt;br&gt; &lt…
#
# [2026-05-01 13:00:34 UTC]  Сообщение клиента (текст/кнопка)
#   👤 КЛИЕНТ
#   ✉  Простите, не понял вас.&lt;br&gt;classification_failed_nayd&lt;br&gt;=======&lt;br&gt;CraftTalk&lt;br&gt; &lt;br&gt; &lt…
#
# [2026-05-01 13:00:35 UTC]  Сообщение клиента (текст/кнопка)
#   🤖 aiassist2
#   ✉  Простите, не понял вас. classification_failed_nayd
#
# [2026-05-01 13:00:35 UTC]  Сообщение клиента (текст/кнопка)
#   🤖 aiassist2
#   ✉  Простите, не понял вас. classification_failed_nayd
#
# [2026-05-01 13:00:36 UTC]  Прочитано клиентом
#   👤 КЛИЕНТ
#
# [2026-05-01 13:00:37 UTC]  Сообщение клиента (текст/кнопка)
#   👤 КЛИЕНТ
#   ✉  Простите, не понял вас.&lt;br&gt;classification_failed_nayd&lt;br&gt;=======&lt;br&gt;CraftTalk&lt;br&gt; &lt;br&gt; &lt…
#
# [2026-05-01 13:00:38 UTC]  Прочитано клиентом
#   👤 КЛИЕНТ
#
# [2026-05-01 13:00:38 UTC]  Сообщение клиента (текст/кнопка)
#   🤖 aiassist2
#   ✉  Простите, не понял вас. classification_failed_nayd
#
# [2026-05-01 13:00:39 UTC]  Прочитано клиентом
#   👤 КЛИЕНТ
#
# [2026-05-01 13:03:38 UTC]  Сообщение клиента (текст/кнопка)
#   🤖 timerservice
#   ✉  Таймаут - 1
#
# [2026-05-01 13:03:40 UTC]  Прочитано клиентом
#   👤 КЛИЕНТ
#
# [2026-05-01 13:04:45 UTC]  Сообщение клиента (текст/кнопка)
#   🤖 timerservice
#   ✉  Диалог завершен
#
# [2026-05-01 13:04:45 UTC]  Диалог завершён оператором
#   🤖 timerservice
#   ✉  dialogs-controller.noty.timeout
#
# ══════════════════════════════════════════════════════════════════════
#   СТАТИСТИКА
# ══════════════════════════════════════════════════════════════════════
#   Распределение событий по типам:
#        1 — Сообщение клиента (текст/кнопка): 28
#        2 — Прочитано клиентом: 10
#        5 — Type 5: 6
#       16 — Диалог завершён оператором: 1
#       30 — Системная команда бота: 46
#       33 — Инициализация диалога: 1
#
#   Текстовых сообщений от клиента: 11
#     → Простите, не понял вас.&lt;br&gt;classification_failed_nayd&lt;br&gt;=======&lt;br&gt;CraftTalk&lt;br&gt;
# &lt;br&gt;
# &lt
#     → Таймаут - 1&lt;br&gt;=======&lt;br&gt;CraftTalk&lt;br&gt;
# &lt;br&gt;
# &lt;div&gt;01.05.2026 11:10, buggy4test@mail.ru:&lt
#     → Таймаут - 1&lt;br&gt;=======&lt;br&gt;CraftTalk&lt;br&gt;
# &lt;br&gt;
# &lt;div&gt;01.05.2026 11:10, mailer-daemon@corp.mai
#     → Таймаут - 2&lt;br&gt;=======&lt;br&gt;CraftTalk&lt;br&gt;
# &lt;br&gt;
# &lt;div&gt;01.05.2026 11:12, buggy4test@mail.ru:&lt
#     → Таймаут - 2&lt;br&gt;=======&lt;br&gt;CraftTalk&lt;br&gt;
# &lt;br&gt;
# &lt;div&gt;01.05.2026 11:12, mailer-daemon@corp.mai
#     → Простите, не понял вас.&lt;br&gt;classification_failed_nayd&lt;br&gt;=======&lt;br&gt;CraftTalk&lt;br&gt;
# &lt;br&gt;
# &lt
#     → Простите, не понял вас.&lt;br&gt;classification_failed_nayd&lt;br&gt;=======&lt;br&gt;CraftTalk&lt;br&gt;
# &lt;br&gt;
# &lt
#     → Простите, не понял вас.&lt;br&gt;classification_failed_nayd&lt;br&gt;=======&lt;br&gt;CraftTalk&lt;br&gt;
# &lt;br&gt;
# &lt
#     → Простите, не понял вас.&lt;br&gt;classification_failed_nayd&lt;br&gt;=======&lt;br&gt;CraftTalk&lt;br&gt;
# &lt;br&gt;
# &lt
#     → Простите, не понял вас.&lt;br&gt;classification_failed_nayd&lt;br&gt;=======&lt;br&gt;CraftTalk&lt;br&gt;
# &lt;br&gt;
# &lt
#     → Простите, не понял вас.&lt;br&gt;classification_failed_nayd&lt;br&gt;=======&lt;br&gt;CraftTalk&lt;br&gt;
# &lt;br&gt;
# &lt
#
#   Ответов операторов: 0
#
#   Переключений бота (switchredirect): 1
#     → /switchredirect aiassist2_nayd intent_id="block_a29a57"
#
#
# ══════════════════════════════════════════════════════════════════════
#   БОТ: путь интентов и содержимое статей
# ══════════════════════════════════════════════════════════════════════
#
# ============================================================
# ARTICLE: article-c7d16856-4f78-4260-abfb-371c111153a6
